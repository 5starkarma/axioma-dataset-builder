# %%
# EXTRAS
 
# Image resizer function
 
# NOTES
 
# Can we cache anywhere to speed it up? Check DLwPT book for caching section

# %%
% cd /content/drive/My\ Drive/Colab\ Notebooks/axioma

# %%
# !pip install -U PyYAML wget imgaug

# %%
# !rm -r /content/drive/My\ Drive/Colab\ Notebooks/axioma/axioma

# %%
# !zip -r /content/axioma_val.zip /content/axioma

# %%
# from google.colab import files
# files.download('/content/axioma.zip')

# %%
# !cp -r /content/axioma_val.zip /content/drive/My\ Drive/Colab\ Notebooks/axioma

# %%
# !mv -v /content/axioma/labels/train/* /content/drive/My\ Drive/Colab\ Notebooks/axioma/axioma/labels/train/

# %%
# ls /content/axioma/images/train | wc -l

# %%
# !rm -r /content/axioma

# %%
! python3 dataset/build.py --size 50000
# Out:
# ...
# Num of card images: 52
#   1% 268/50000 [11:14<19:25:10,  1.41s/it]Image failed to resize. Retrying..
#  30% 14871/50000 [10:44:25<18:44:52,  1.92s/it]Image failed to resize. Retrying..
#  32% 15983/50000 [11:34:23<25:44:42,  2.72s/it]Image failed to resize. Retrying..
#  45% 22727/50000 [16:28:07<27:18:54,  3.61s/it]Image failed to resize. Retrying..
#  59% 29495/50000 [21:25:16<16:29:27,  2.90s/it]Image failed to resize. Retrying..
#  63% 31547/50000 [22:53:46<12:49:15,  2.50s/it]Image failed to resize. Retrying..
#  66% 33080/50000 [23:59:14<15:53:32,  3.38s/it]
